# %% [markdown]
# <a href="https://colab.research.google.com/github/kerondavid-debug/Project-1-CNN/blob/main/Model_4Project_1_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets  import cifar10
from tensorflow.keras.utils import to_categorical

# Load cifar10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2093s 12us/step

# %%
# Normalize the images
x_train_normalized = x_train.astype('float32') / 255.0
x_test_normalized = x_test.astype('float32') / 255.0

# %%
from sklearn.model_selection import train_test_split

# Temporary holder for the 30% remaining data after the first split
x_train_sub, x_temp, y_train_sub, y_temp = train_test_split(
    x_train_normalized, y_train,
    test_size=0.3,
    stratify=y_train,
    random_state=42)

# Splitting the temporary holder into 15% validation data and 15% test data
x_val, x_test, y_val, y_test = train_test_split(
    x_temp, y_temp, # Use x_temp directly, as it is already normalized
    test_size=0.5,
    stratify=y_temp,
    random_state=42)

# %%
# Encoding the dataset
y_train_encoded = to_categorical(y_train_sub, num_classes=10)
y_val_encoded = to_categorical(y_val, num_classes=10)
y_test_encoded = to_categorical(y_test, num_classes=10)

# %%
# Visualization
# Define the class names for CIFAR-10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Get 10 random indices to display images
num_images_to_display = 10
random_indices = np.random.choice(x_train_sub.shape[0], num_images_to_display, replace=False)

plt.figure(figsize=(12, 6))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1) # Arrange in 2 rows, 5 columns
    plt.imshow(x_train_sub[idx]) # Display the normalized image
    plt.title(f"Label: {class_names[np.argmax(y_train_encoded[idx])]}") # Get original label
    plt.axis('off')
plt.suptitle('Sample CIFAR-10 Training Images', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Class Distributiion in training, validating and test sets using barcharts after using stratify.
import seaborn as sns
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('Class Distribution Across Datasets', fontsize=16)

# Training set distribution
sns.countplot(x=np.argmax(y_train_encoded, axis=1), ax=axes[0], palette='viridis')
axes[0].set_title('Training Set Class Distribution')
axes[0].set_xlabel('Class ID')
axes[0].set_ylabel('Count')
axes[0].set_xticklabels(class_names, rotation=45, ha='right')

# Validation set distribution
sns.countplot(x=np.argmax(y_val_encoded, axis=1), ax=axes[1], palette='viridis')
axes[1].set_title('Validation Set Class Distribution')
axes[1].set_xlabel('Class ID')
axes[1].set_ylabel('Count')
axes[1].set_xticklabels(class_names, rotation=45, ha='right')

# Test set distribution
sns.countplot(x=np.argmax(y_test_encoded, axis=1), ax=axes[2], palette='viridis')
axes[2].set_title('Test Set Class Distribution')
axes[2].set_xlabel('Class ID')
axes[2].set_ylabel('Count')
axes[2].set_xticklabels(class_names, rotation=45, ha='right')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# /tmp/ipykernel_2154/568526296.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=np.argmax(y_train_encoded, axis=1), ax=axes[0], palette='viridis')
# /tmp/ipykernel_2154/568526296.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(class_names, rotation=45, ha='right')
# /tmp/ipykernel_2154/568526296.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=np.argmax(y_val_encoded, axis=1), ax=axes[1], palette='viridis')
# /tmp/ipykernel_2154/568526296.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(class_names, rotation=45, ha='right')
# /tmp/ipykernel_2154/568526296.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=np.argmax(y_test_encoded, axis=1), ax=axes[2], palette='viridis')
# /tmp/ipykernel_2154/568526296.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_xticklabels(class_names, rotation=45, ha='right')

# %% [markdown]
# ### Convolutional Neural Network (CNN) Architecture Design
#
# Now, let's define the CNN model using `tf.keras.models.Sequential`. The architecture will include:
#
# *   **Convolutional Layers (`Conv2D`)**: To extract features from the input images.
# *   **Activation Functions (`ReLU`)**: To introduce non-linearity.
# *   **Max Pooling Layers (`MaxPooling2D`)**: To reduce spatial dimensions and make the model more robust to variations.
# *   **Dropout Layers (`Dropout`)**: To prevent overfitting by randomly setting a fraction of input units to 0 at each update during training time.
# *   **Flatten Layer (`Flatten`)**: To convert the 2D feature maps into a 1D vector for the fully connected layers.
# *   **Dense Layers (`Dense`)**: Fully connected layers for classification.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer, BatchNormalization
from tensorflow.keras.layers import RandomFlip, RandomRotation # Import augmentation layers

# Define the input shape (height, width, channels) for CIFAR-10 images
input_shape = x_train_sub.shape[1:] # (32, 32, 3)
num_classes = 10

model = Sequential([
    InputLayer(shape=input_shape),
    # Data Augmentation Layers
    RandomFlip("horizontal"),
    RandomRotation(0.05),

    # First Convolutional Block
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Second Convolutional Block
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Third Convolutional Block
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Flatten and Dense Layers
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation='softmax') # Output layer for 10 classes
])

# Display the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 32, 32, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,345,066 (5.13 MB)
#  Trainable params: 1,343,146 (5.12 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %% [markdown]
# ### Current Model Configuration: With Batch Normalization and Dropout
#
# The current model architecture now includes `BatchNormalization` layers after each `Conv2D` layer, in addition to the `Dropout` layers. This combination is typically used to improve training stability and reduce overfitting.
#
# To evaluate the impact of these changes, the model needs to be re-compiled and re-trained.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Define Callbacks
# Early Stopping: Monitor validation loss and stop if it doesn't improve for 10 epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True);

# Train the model
history = model.fit(x_train_sub, y_train_encoded,
                    epochs=20,
                    batch_size=64,
                    validation_data=(x_val, y_val_encoded),
                    callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - accuracy: 0.4078 - loss: 1.7980 - val_accuracy: 0.4639 - val_loss: 1.5752
# Epoch 2/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5553 - loss: 1.2438 - val_accuracy: 0.5327 - val_loss: 1.3942
# Epoch 3/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6263 - loss: 1.0614 - val_accuracy: 0.6336 - val_loss: 1.1387
# Epoch 4/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6688 - loss: 0.9422 - val_accuracy: 0.7079 - val_loss: 0.8449
# Epoch 5/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6934 - loss: 0.8717 - val_accuracy: 0.6776 - val_loss: 0.9588
# Epoch 6/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7133 - loss: 0.8185 - val_accuracy: 0.7445 - val_loss: 0.7680
# Epoch 7/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7344 - loss: 0.7649 - val_accuracy: 0.7609 - val_loss: 0.6894
# Epoch 8/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7452 - loss: 0.7305 - val_accuracy: 0.6861 - val_loss: 0.9934
# Epoch 9/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7543 - loss: 0.7086 - val_accuracy: 0.7439 - val_loss: 0.7487
# Epoch 10/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7657 - loss: 0.6760 - val_accuracy: 0.7484 - val_loss: 0.7335
# Epoch 11/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7723 - loss: 0.6489 - val_accuracy: 0.7813 - val_loss: 0.6399
# Epoch 12/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7798 - loss: 0.6305 - val_accuracy: 0.7931 - val_loss: 0.6057
# Epoch 13/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7899 - loss: 0.6085 - val_accuracy: 0.7832 - val_loss: 0.6460
# Epoch 14/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.7909 - loss: 0.5944 - val_accuracy: 0.8121 - val_loss: 0.5536
# Epoch 15/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.8000 - loss: 0.5689 - val_accuracy: 0.7683 - val_loss: 0.6985
# Epoch 16/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.8037 - loss: 0.5578 - val_accuracy: 0.8171 - val_loss: 0.5376
# Epoch 17/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.8112 - loss: 0.5421 - val_accuracy: 0.7812 - val_loss: 0.6617
# Epoch 18/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.8144 - loss: 0.5365 - val_accuracy: 0.8249 - val_loss: 0.5037
# Epoch 19/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.8217 - loss: 0.5115 - val_accuracy: 0.8281 - val_loss: 0.5110
# Epoch 20/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.8214 - loss: 0.5109 - val_accuracy: 0.8104 - val_loss: 0.5644

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import pandas as pd

# Convert the history.history dict to a pandas DataFrame for a clean tabular format
history_df = pd.DataFrame(history.history)
display(history_df.head())

# You can also get a summary of the best epoch based on validation loss
best_epoch = history_df['val_loss'].idxmin()
print(f"Best epoch based on validation loss: {best_epoch + 1}")
print(f"Validation Loss at best epoch: {history_df.loc[best_epoch, 'val_loss']:.4f}")
print(f"Validation Accuracy at best epoch: {history_df.loc[best_epoch, 'val_accuracy']:.4f}")
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.407771  1.797984      0.463867  1.575206
# 1  0.555257  1.243850      0.532667  1.394160
# 2  0.626257  1.061400      0.633600  1.138654
# 3  0.668829  0.942208      0.707867  0.844946
# 4  0.693371  0.871721      0.677600  0.958827
# Best epoch based on validation loss: 18
# Validation Loss at best epoch: 0.5037
# Validation Accuracy at best epoch: 0.8249

# %%
import matplotlib.pyplot as plt

# Create a figure with two subplots for accuracy and loss
plt.figure(figsize=(14, 6))

# Subplot 1: Training and Validation Accuracy
plt.subplot(1, 2, 1) # (rows, columns, panel number)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Model Accuracy over Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=12)
plt.xlabel('Epoch', fontsize=12)
plt.legend(loc='lower right')
plt.grid(True, linestyle='--', alpha=0.7)

# Subplot 2: Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss over Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=12)
plt.xlabel('Epoch', fontsize=12)
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
import seaborn as sns
import numpy as np

# Make predictions on the test set
y_pred_encoded = model.predict(x_test)
y_pred = np.argmax(y_pred_encoded, axis=1)
y_true = np.argmax(y_test_encoded, axis=1)

# Calculate overall accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Test Accuracy: {accuracy:.4f}")

# Calculate precision, recall, f1-score for each class
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=np.arange(len(class_names)))

print("\nClass-wise Metrics:")
for i, class_name in enumerate(class_names):
    print(f"  {class_name:<10}: Precision={precision[i]:.4f}, Recall={recall[i]:.4f}, F1-score={f1_score[i]:.4f}")

# Calculate macro-averaged metrics
precision_macro, recall_macro, f1_score_macro, _ = precision_recall_fscore_support(y_true, y_pred, average='macro')
print(f"\nMacro-averaged Precision: {precision_macro:.4f}")
print(f"Macro-averaged Recall: {recall_macro:.4f}")
print(f"Macro-averaged F1-score: {f1_score_macro:.4f}")
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Test Accuracy: 0.8249
#
# Class-wise Metrics:
#   airplane  : Precision=0.8847, Recall=0.8387, F1-score=0.8611
#   automobile: Precision=0.9008, Recall=0.9200, F1-score=0.9103
#   bird      : Precision=0.8457, Recall=0.7013, F1-score=0.7668
#   cat       : Precision=0.7107, Recall=0.6747, F1-score=0.6922
#   deer      : Precision=0.7861, Recall=0.8133, F1-score=0.7995
#   dog       : Precision=0.8197, Recall=0.6547, F1-score=0.7279
#   frog      : Precision=0.7735, Recall=0.9200, F1-score=0.8404
#   horse     : Precision=0.8171, Recall=0.8813, F1-score=0.8480
#   ship      : Precision=0.9130, Recall=0.8960, F1-score=0.9044
#   truck     : Precision=0.8119, Recall=0.9493, F1-score=0.8752
#
# Macro-averaged Precision: 0.8263
# Macro-averaged Recall: 0.8249
# Macro-averaged F1-score: 0.8226

# %%
# Visualize the confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(f"Best epoch based on validation loss: {best_epoch + 1}")

current_model_training_accuracy = history_df.loc[best_epoch, 'accuracy']
current_model_validation_accuracy = history_df.loc[best_epoch, 'val_accuracy']
current_model_validation_loss = history_df.loc[best_epoch, 'val_loss']

print(f"\nModel Metrics (at best epoch {best_epoch + 1}):")
print(f"  Training Accuracy: {current_model_training_accuracy:.4f}")
print(f"  Validation Accuracy: {current_model_validation_accuracy:.4f}")
print(f"  Validation Loss: {current_model_validation_loss:.4f}")
print(f"  Test Accuracy: {accuracy:.4f}")
# Out:
# Best epoch based on validation loss: 18
#
# Model Metrics (at best epoch 18):
#   Training Accuracy: 0.8144
#   Validation Accuracy: 0.8249
#   Validation Loss: 0.5037
#   Test Accuracy: 0.8249

# %%
model.save("Base-Model.keras")
from google.colab import drive
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/Base-Model.keras')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Implementing Transfer Learning with VGG16
#
# Now, let's explore transfer learning using a pre-trained VGG16 model. We will use the VGG16 model, pre-trained on ImageNet, as a feature extractor. Its convolutional base will be kept frozen, and a new classification head will be trained on top of it for the CIFAR-10 dataset. This approach leverages the powerful feature learning capabilities of VGG16.
#
# Crucially, we will **not** include data augmentation in this model, as requested by you.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.optimizers import Adam

# Define the input shape for CIFAR-10 images
input_shape_vgg = (32, 32, 3)
num_classes = 10

# Load the VGG16 model pre-trained on ImageNet, excluding the top (fully connected) layers
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=input_shape_vgg)

# Freeze the layers of the VGG16 base model
for layer in vgg_base.layers:
    layer.trainable = False

# Create a new model on top of the VGG16 base
# Define the input layer explicitly for the new model
inputs = Input(shape=input_shape_vgg)
x = vgg_base(inputs, training=False) # Ensure the base model is not trained
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dense(num_classes, activation='softmax')(x)

vgg_model = Model(inputs, x)

# Compile the model
vgg_model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Display the model summary
vgg_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 1, 1, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,586 (56.64 MB)
#  Trainable params: 133,898 (523.04 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# The VGG16-based model is now defined with its convolutional base frozen and a new classification head added. Next, we will train this model.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define Callbacks
# Early Stopping: Monitor validation loss and stop if it doesn't improve for 10 epochs
early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the VGG16 model
history_vgg = vgg_model.fit(x_train_sub, y_train_encoded,
                            epochs=20,
                            batch_size=64,
                            validation_data=(x_val, y_val_encoded),
                            callbacks=[early_stopping_vgg])
# Out:
# Epoch 1/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5013 - loss: 1.4288 - val_accuracy: 0.5709 - val_loss: 1.2525
# Epoch 2/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.5757 - loss: 1.2123 - val_accuracy: 0.5851 - val_loss: 1.1957
# Epoch 3/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.5977 - loss: 1.1516 - val_accuracy: 0.5997 - val_loss: 1.1586
# Epoch 4/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.6134 - loss: 1.1069 - val_accuracy: 0.6079 - val_loss: 1.1399
# Epoch 5/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6257 - loss: 1.0670 - val_accuracy: 0.6025 - val_loss: 1.1381
# Epoch 6/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6355 - loss: 1.0358 - val_accuracy: 0.5947 - val_loss: 1.1631
# Epoch 7/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6493 - loss: 1.0021 - val_accuracy: 0.6111 - val_loss: 1.1190
# Epoch 8/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6583 - loss: 0.9724 - val_accuracy: 0.6212 - val_loss: 1.1053
# Epoch 9/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6716 - loss: 0.9396 - val_accuracy: 0.6135 - val_loss: 1.1166
# Epoch 10/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6825 - loss: 0.9129 - val_accuracy: 0.6201 - val_loss: 1.1035
# Epoch 11/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6904 - loss: 0.8853 - val_accuracy: 0.6208 - val_loss: 1.1051
# Epoch 12/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6980 - loss: 0.8578 - val_accuracy: 0.6176 - val_loss: 1.1274
# Epoch 13/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.7083 - loss: 0.8328 - val_accuracy: 0.6141 - val_loss: 1.1166
# Epoch 14/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7182 - loss: 0.8061 - val_accuracy: 0.6172 - val_loss: 1.1288
# Epoch 15/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.7285 - loss: 0.7796 - val_accuracy: 0.6271 - val_loss: 1.1170
# Epoch 16/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.7373 - loss: 0.7568 - val_accuracy: 0.6187 - val_loss: 1.1356
# Epoch 17/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7447 - loss: 0.7350 - val_accuracy: 0.6208 - val_loss: 1.1458
# Epoch 18/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.7555 - loss: 0.7083 - val_accuracy: 0.6176 - val_loss: 1.1839
# Epoch 19/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7615 - loss: 0.6866 - val_accuracy: 0.6201 - val_loss: 1.1709
# Epoch 20/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7720 - loss: 0.6650 - val_accuracy: 0.6185 - val_loss: 1.1716

# %%
import pandas as pd

# Convert the history_vgg.history dict to a pandas DataFrame
history_vgg_df = pd.DataFrame(history_vgg.history)
display(history_vgg_df.head())

# Summary of the best epoch for the VGG16 model
best_epoch_vgg = history_vgg_df['val_loss'].idxmin()
print(f"Best epoch for VGG16 based on validation loss: {best_epoch_vgg + 1}")
print(f"Validation Loss at best epoch for VGG16: {history_vgg_df.loc[best_epoch_vgg, 'val_loss']:.4f}")
print(f"Validation Accuracy at best epoch for VGG16: {history_vgg_df.loc[best_epoch_vgg, 'val_accuracy']:.4f}")
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.501286  1.428780      0.570933  1.252466
# 1  0.575714  1.212340      0.585067  1.195695
# 2  0.597714  1.151581      0.599733  1.158641
# 3  0.613429  1.106922      0.607867  1.139931
# 4  0.625714  1.066972      0.602533  1.138084
# Best epoch for VGG16 based on validation loss: 10
# Validation Loss at best epoch for VGG16: 1.1035
# Validation Accuracy at best epoch for VGG16: 0.6201

# %%
import matplotlib.pyplot as plt

# Create a figure with two subplots for accuracy and loss for VGG16 model
plt.figure(figsize=(14, 6))

# Subplot 1: Training and Validation Accuracy
plt.subplot(1, 2, 1) # (rows, columns, panel number)
plt.plot(history_vgg.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history_vgg.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('VGG16 Model Accuracy over Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=12)
plt.xlabel('Epoch', fontsize=12)
plt.legend(loc='lower right')
plt.grid(True, linestyle='--', alpha=0.7)

# Subplot 2: Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(history_vgg.history['loss'], label='Train Loss', color='blue')
plt.plot(history_vgg.history['val_loss'], label='Validation Loss', color='orange')
plt.title('VGG16 Model Loss over Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=12)
plt.xlabel('Epoch', fontsize=12)
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# Now, let's evaluate the performance of the VGG16 model on the test set.

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
import seaborn as sns
import numpy as np

# Make predictions on the test set using the VGG16 model
y_pred_encoded_vgg = vgg_model.predict(x_test)
y_pred_vgg = np.argmax(y_pred_encoded_vgg, axis=1)
y_true_vgg = np.argmax(y_test_encoded, axis=1)

# Calculate overall accuracy for VGG16
accuracy_vgg = accuracy_score(y_true_vgg, y_pred_vgg)
print(f"VGG16 Test Accuracy: {accuracy_vgg:.4f}")

# Calculate precision, recall, f1-score for each class (VGG16)
precision_vgg, recall_vgg, f1_score_vgg, _ = precision_recall_fscore_support(y_true_vgg, y_pred_vgg, average=None, labels=np.arange(len(class_names)))

print("\nVGG16 Class-wise Metrics:")
for i, class_name_val in enumerate(class_names):
    print(f"  {class_name_val:<10}: Precision={precision_vgg[i]:.4f}, Recall={recall_vgg[i]:.4f}, F1-score={f1_score_vgg[i]:.4f}")

# Calculate macro-averaged metrics (VGG16)
precision_macro_vgg, recall_macro_vgg, f1_score_macro_vgg, _ = precision_recall_fscore_support(y_true_vgg, y_pred_vgg, average='macro')
print(f"\nVGG16 Macro-averaged Precision: {precision_macro_vgg:.4f}")
print(f"VGG16 Macro-averaged Recall: {recall_macro_vgg:.4f}")
print(f"VGG16 Macro-averaged F1-score: {f1_score_macro_vgg:.4f}")
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# VGG16 Test Accuracy: 0.6124
#
# VGG16 Class-wise Metrics:
#   airplane  : Precision=0.7180, Recall=0.6587, F1-score=0.6871
#   automobile: Precision=0.6608, Recall=0.6493, F1-score=0.6550
#   bird      : Precision=0.5265, Recall=0.5293, F1-score=0.5279
#   cat       : Precision=0.4204, Recall=0.5667, F1-score=0.4827
#   deer      : Precision=0.5686, Recall=0.5693, F1-score=0.5690
#   dog       : Precision=0.5600, Recall=0.5227, F1-score=0.5407
#   frog      : Precision=0.6618, Recall=0.6627, F1-score=0.6622
#   horse     : Precision=0.7018, Recall=0.6307, F1-score=0.6643
#   ship      : Precision=0.6961, Recall=0.7667, F1-score=0.7297
#   truck     : Precision=0.7007, Recall=0.5680, F1-score=0.6274
#
# VGG16 Macro-averaged Precision: 0.6215
# VGG16 Macro-averaged Recall: 0.6124
# VGG16 Macro-averaged F1-score: 0.6146

# %%
# Visualize the confusion matrix for VGG16
cm_vgg = confusion_matrix(y_true_vgg, y_pred_vgg)

plt.figure(figsize=(10, 8))
sns.heatmap(cm_vgg, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('VGG16 Confusion Matrix')
plt.show()

# %%
print(f"Best epoch for VGG16 based on validation loss: {best_epoch_vgg + 1}")

current_model_training_accuracy_vgg = history_vgg_df.loc[best_epoch_vgg, 'accuracy']
current_model_validation_accuracy_vgg = history_vgg_df.loc[best_epoch_vgg, 'val_accuracy']
current_model_validation_loss_vgg = history_vgg_df.loc[best_epoch_vgg, 'val_loss']

print(f"\nVGG16 Model Metrics (at best epoch {best_epoch_vgg + 1}):")
print(f"  Training Accuracy: {current_model_training_accuracy_vgg:.4f}")
print(f"  Validation Accuracy: {current_model_validation_accuracy_vgg:.4f}")
print(f"  Validation Loss: {current_model_validation_loss_vgg:.4f}")
print(f"  Test Accuracy: {accuracy_vgg:.4f}")
# Out:
# Best epoch for VGG16 based on validation loss: 10
#
# VGG16 Model Metrics (at best epoch 10):
#   Training Accuracy: 0.6825
#   Validation Accuracy: 0.6201
#   Validation Loss: 1.1035
#   Test Accuracy: 0.6124
