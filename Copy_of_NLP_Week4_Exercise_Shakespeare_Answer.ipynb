# %% [markdown]
# <a href="https://colab.research.google.com/github/kerondavid-debug/Project-1-CNN/blob/main/Copy_of_NLP_Week4_Exercise_Shakespeare_Answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab | Text Generation from Shakespeare's Sonnet
#
# This notebook explores the fascinating domain of text generation using a deep learning model trained on Shakespeare's sonnets.
#
# The objective is to create a neural network capable of generating text sequences that mimic the style and language of Shakespeare.
#
# By utilizing a Recurrent Neural Network (RNN) with Long Short-Term Memory (LSTM) layers, this project aims to demonstrate how a model can learn and replicate the complex patterns of early modern English.
#
# The dataset used consists of Shakespeare's sonnets, which are preprocessed and tokenized to serve as input for the model.
#
# Throughout this notebook, you will see the steps taken to prepare the data, build and train the model, and evaluate its performance in generating text.
#
# This lab provides a hands-on approach to understanding the intricacies of natural language processing (NLP) and the potential of machine learning in creative text generation.

# %% [markdown]
# Let's import necessary libraries
#
# We will use TensorFlow/Keras for the model, NumPy for array work, and Matplotlib later to visualize training results.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import tensorflow.keras.utils as ku
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Let's get the data!
#
# This cell downloads the sonnets file, reads it into memory, and splits it into lowercase lines for training.

# %%
import requests
url = 'https://raw.githubusercontent.com/martin-gorner/tensorflow-rnn-shakespeare/master/shakespeare/sonnets.txt'
resp = requests.get(url)
with open('sonnets.txt', 'wb') as f:
    f.write(resp.content)

data = open('sonnets.txt').read()

corpus = data.lower().split("\n")

# %% [markdown]
# Step 1: Initialise a tokenizer and fit it on the corpus variable using .fit_on_texts

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# %% [markdown]
# Step 2: Calculate the Vocabulary Size
#
# Let's figure out how many unique words are in your corpus. This will be the size of your vocabulary.
#
# Calculate the length of tokenizer.word_index, add 1 to it and store it in a variable called total_words.

# %%
total_words = len(tokenizer.word_index) + 1
total_words
# Out:
# 3375

# %% [markdown]
# Create an empty list called input_sequences.
#
# For each sentence in your corpus, convert the text into a sequence of integers using the tokenizer.
# Then, generate n-gram sequences from these tokens.
#
# Store the result in the list input_sequences.

# %%
input_sequences = []

for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[: i + 1]
        input_sequences.append(n_gram_sequence)

len(input_sequences)
# Out:
# 15484

# %% [markdown]
# Calculate the length of the longest sequence in input_sequences. Assign the result to a variable called max_sequence_len.
#
# Now pad the sequences using pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre').
# Convert it to a numpy array and assign the result back to our variable called input_sequences.

# %%
max_sequence_len = max(len(sequence) for sequence in input_sequences)
input_sequences = np.array(
    pad_sequences(input_sequences, maxlen=max_sequence_len, padding="pre")
)

input_sequences.shape
# Out:
# (15484, 11)

# %% [markdown]
# Prepare Predictors and Labels
#
# Split the sequences into two parts:
#
# - Predictors: All elements from input_sequences except the last one.
# - Labels: The last element of each sequence in input_sequences.

# %%
predictors, labels = input_sequences[:, :-1], input_sequences[:, -1]

predictors.shape, labels.shape
# Out:
# ((15484, 10), (15484,))

# %% [markdown]
# One-Hot Encode the Labels :
#
# Convert the labels (which are integers) into one-hot encoded vectors.
#
# Ensure the length of these vectors matches the total number of unique words in your vocabulary.
#
# Use ku.to_categorical() on labels with num_classes = total_words
#
# Assign the result back to our variable labels.

# %%
labels = ku.to_categorical(labels, num_classes=total_words)

labels.shape
# Out:
# (15484, 3375)

# %% [markdown]
# # Initialize the Model
#
# Start by creating a Sequential model.
#
# Add Layers to the Model:
#
# Embedding Layer: The first layer is an embedding layer. It converts word indices into dense vectors of fixed size (100 in this case). Set the input length to the maximum sequence length minus one, which corresponds to the number of previous words the model will consider when predicting the next word.
#
# Bidirectional LSTM Layer: Add a Bidirectional LSTM layer with 150 units. This layer allows the model to learn context from both directions (past and future) in the sequence. return_sequences=True
#
# Dropout Layer: Add a dropout layer with a rate of 0.2 to prevent overfitting by randomly setting 20% of the input units to 0 during training.
#
# LSTM Layer: Add a second LSTM layer with 100 units. This layer processes the sequence and passes its output to the next layer.
#
# Dense Layer (Intermediate): Add a dense layer with half the total number of words as units, using ReLU activation. A regularization term (L2) is added to prevent overfitting.
#
# Dense Layer (Output): The final dense layer has as many units as there are words in the vocabulary, with a softmax activation function to output a probability distribution over all words.

# %%
model = Sequential([
    Input(shape=(max_sequence_len - 1,)),
    Embedding(total_words, 100),
    Bidirectional(LSTM(150, return_sequences=True)),
    Dropout(0.2),
    LSTM(100),
    Dense(total_words // 2, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
    Dense(total_words, activation="softmax"),
])

# %% [markdown]
# # Compile the Model:
#
# Compile the model using categorical crossentropy as the loss function, the Adam optimizer for efficient training, and accuracy as the metric to evaluate during training.

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=0.01),
    metrics=["accuracy"],
)

# %% [markdown]
# # Print Model Summary:
#
# Use model.summary() to print a summary of the model, which shows the layers, their output shapes, and the number of parameters.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 10, 100)        │       337,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 10, 300)        │       301,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 300)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100)            │       160,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1687)           │       170,387 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3375)           │     5,697,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,666,487 (25.43 MB)
#  Trainable params: 6,666,487 (25.43 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Now train the model for 50 epochs and assign it to a variable called history.
#
# Training the model with 50 epochs should get you around 40% accuracy.
#
# You can train the model for as many epochs as you like depending on the time and computing constraints you are facing. Ideally train it for a larger amount of epochs than 50.
#
# That way you will get better text generation at the end.
#
# However, dont waste your time.

# %%
history = model.fit(predictors, labels, epochs=70, verbose=1)
# Out:
# Epoch 1/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0619 - loss: 5.4902
# Epoch 2/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0638 - loss: 5.4871
# Epoch 3/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.0641 - loss: 5.4821
# Epoch 4/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0654 - loss: 5.4610
# Epoch 5/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0635 - loss: 5.4539
# Epoch 6/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0652 - loss: 5.4423
# Epoch 7/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0640 - loss: 5.4606
# Epoch 8/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0646 - loss: 5.4500
# Epoch 9/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0626 - loss: 5.4526
# Epoch 10/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0650 - loss: 5.4438
# Epoch 11/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.0645 - loss: 5.4348
# Epoch 12/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0650 - loss: 5.4313
# Epoch 13/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0646 - loss: 5.4527
# Epoch 14/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.0654 - loss: 5.4385
# Epoch 15/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0646 - loss: 5.4315
# Epoch 16/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0658 - loss: 5.4339
# Epoch 17/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0630 - loss: 5.4404
# Epoch 18/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0650 - loss: 5.4346
# Epoch 19/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0648 - loss: 5.4510
# Epoch 20/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0663 - loss: 5.4266
# Epoch 21/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0639 - loss: 5.4375
# Epoch 22/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.0665 - loss: 5.4458
# Epoch 23/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0650 - loss: 5.4369
# Epoch 24/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.0660 - loss: 5.4274
# Epoch 25/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0657 - loss: 5.4447
# Epoch 26/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0655 - loss: 5.4329
# Epoch 27/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0645 - loss: 5.4336
# Epoch 28/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0644 - loss: 5.4377
# Epoch 29/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0626 - loss: 5.4323
# Epoch 30/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0648 - loss: 5.4721
# Epoch 31/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0645 - loss: 5.4769
# Epoch 32/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0639 - loss: 5.4411
# Epoch 33/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0634 - loss: 5.4512
# Epoch 34/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0661 - loss: 5.4563
# Epoch 35/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0636 - loss: 5.4434
# Epoch 36/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0652 - loss: 5.4431
# Epoch 37/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0661 - loss: 5.4381
# Epoch 38/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0647 - loss: 5.4358
# Epoch 39/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0652 - loss: 5.4304
# Epoch 40/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0643 - loss: 5.4266
# Epoch 41/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0656 - loss: 5.4351
# Epoch 42/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0643 - loss: 5.4478
# Epoch 43/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0666 - loss: 5.4152
# Epoch 44/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0648 - loss: 5.4275
# Epoch 45/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0648 - loss: 5.4389
# Epoch 46/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0643 - loss: 5.4381
# Epoch 47/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.0644 - loss: 5.4470
# Epoch 48/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0664 - loss: 5.4392
# Epoch 49/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0656 - loss: 5.4666
# Epoch 50/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0662 - loss: 5.4531
# Epoch 51/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0635 - loss: 5.4693
# Epoch 52/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0665 - loss: 5.4410
# Epoch 53/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0666 - loss: 5.4485
# Epoch 54/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.0645 - loss: 5.4378
# Epoch 55/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0644 - loss: 5.4199
# Epoch 56/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0640 - loss: 5.4417
# Epoch 57/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.0628 - loss: 5.4423
# Epoch 58/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0654 - loss: 5.4398
# Epoch 59/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0662 - loss: 5.4280
# Epoch 60/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0651 - loss: 5.4437
# Epoch 61/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0640 - loss: 5.4432
# Epoch 62/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.0645 - loss: 5.4490
# Epoch 63/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.0643 - loss: 5.4460
# Epoch 64/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0654 - loss: 5.4340
# Epoch 65/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0654 - loss: 5.4544
# Epoch 66/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.0652 - loss: 5.4445
# Epoch 67/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0649 - loss: 5.4555
# Epoch 68/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.0676 - loss: 5.4304
# Epoch 69/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0639 - loss: 5.4418
# Epoch 70/70
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.0664 - loss: 5.4391

# %% [markdown]
# # Use plt from matplotlib to plot the training accuracy over epochs and the loss over epochs
#
# A simple side-by-side chart is enough here so you can quickly see whether the model is learning.

# %% [markdown]
# First you will have to get the accuracy and loss data over epochs, you can do this by using methods on your model.
#
# These values are stored inside the training history object returned by model.fit().

# %%
accuracy = history.history["accuracy"]
loss = history.history["loss"]
epochs = range(1, len(accuracy) + 1)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy)
plt.title("Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.subplot(1, 2, 2)
plt.plot(epochs, loss)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Generate text with the model based on a seed text
#
# Now you will create two variables :
#
# - seed_text = 'Write the text you want the model to use as a starting point to generate the next words'
# - next_words = number_of_words_you_want_the_model_to_generate
#
# Please change number_of_words_you_want_the_model_to_generate by an actual integer.

# %%
seed_text = "shall i compare thee"
next_words = 20

# %% [markdown]
# Now create a loop that runs based on the next_words variable and generates new text based on your seed_text input string. Print the full text with the generated text at the end.
#
# This time you dont get detailed instructions.
#
# Have fun!

# %%
index_to_word = {index: word for word, index in tokenizer.word_index.items()}

def generate_text(seed_text, next_words):
    text = seed_text
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding="pre")
        predicted_probs = model.predict(token_list, verbose=0)
        predicted_index = np.argmax(predicted_probs, axis=-1)[0]
        next_word = index_to_word.get(predicted_index, "")
        if not next_word:
            break
        text += " " + next_word
    return text

print(generate_text(seed_text, next_words))
# Out:
# shall i compare thee i am i am i am world and i am world and i am world and i am world and

# %% [markdown]
# Experiment with at least 3 different seed_text strings and see what happens!
#
# Using a few short prompts makes it easier to compare the style and repetition of the generated output.

# %%
test_seeds = [
    "love is",
    "shall i",
    "when in disgrace",
]

for prompt in test_seeds:
    print(generate_text(prompt, 15))
    print()
# Out:
# love is i am i am i am world and i am world and i am world
#
# shall i am i am i am i am i am world and i am world and
#
# when in disgrace in the world and i am i am world and i am world and i
